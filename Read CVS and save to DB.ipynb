# %%
import pymongo
import pandas

# %%
df = pandas.read_csv('../CSV/Collection_Truong.csv')
df
# Out:
#                     Tên\ntrường\nđại học Tên viết\ntắt  \
# 0   Đại học Công nghệ thông tin Gia Định       GIADINH
# 1                       Đại học Văn Lang           VLU
# 2                            Đại học FPT           FPT
# 3                        Đại học Hoa Sen        HOASEN
# 4                     Đại học Hùng Vương           HVU
# 5            Đại học Kinh tế - Tài chính           UEF
# 6            Đại học Ngoại Ngữ - Tin học        HUFLIT
# 7              Đại học Quốc tế Hồng Bàng           HIU
# 8                Đại học Quốc tế Sài Gòn           SIU
# 9                       Đại học Văn Hiến           VHU
# 10                      Đại Học An Giang           AGU
# 11                             Nhạc Viện       HCMCONS
# 12              Đại học An Ninh Nhân Dân           T47
# 13                     đại học bách khoa            BK
# 14        đại học  công nghiệp thực phẩm          HUFI
# 15                   đại học công nghiệp           IUH
# ...

# %%
client = pymongo.MongoClient("mongodb+srv://admin:G5mwPiDbMSZrVs2d@chatbottuvantuyensinh-acxk9.mongodb.net/test?retryWrites=true&w=majority")
mydb = client["ChatbotTuVanTuyenSinh"]
diemchuan = mydb["DiemChuan"]
khoithi = mydb["KhoiThi"]
truong = mydb["Truong"]

# %%
for index, row in df.iterrows():
    name = row['Viet Tat'].strip().strip('\n').strip('\t')
    full_name = row['Ten Truong'].strip().strip('\n').strip('\t')
    faculty = row['Nganh'].strip().strip('\n').strip('\t')
    khoi = row['Khoi']
    try:
        if isinstance(row['Diem Chuan'], float):
            grade = float(row['Diem Chuan'])
        else:
            grade = float(row['Diem Chuan'].replace(',', '.'))
    except:
        continue
    if isinstance(khoi, str):
        khoi = khoi.replace(',',';')
        if ';' in khoi:
            list_khoi = khoi.split(';')
        else:
            list_khoi = [khoi]
    else:
        list_khoi = list()
    list_khoi = [x.strip() for x in list_khoi]
    
    ins = {
        "Ma Truong" : name,
        "Ten Truong" : full_name,
        "Nganh": faculty,
        "Khoi": list_khoi,
        "Diem Chuan": grade
    }
    
    diemchuan.insert_one(ins)

# %%
df2 = pandas.read_csv('../CSV/Collection_KhoiThi.csv')
df2
# Out:
#     Khoi thi                      To hop mon
# 0        A00           Toán, Vật Lý, Hóa Học
# 1        A01         Toán, Vật Lý, Tiếng Anh
# 2        B00         Toán, Hóa Học, Sinh Học
# 3        C00        Ngữ Văn, Lịch Sử, Địa Lý
# 4        D01        Ngữ Văn, Toán, Tiếng Anh
# ..       ...                             ...
# 185      V07    Toán, tiếng Đức, Vẽ mỹ thuật
# 186      V08    Toán, tiếng Nga, Vẽ mỹ thuật
# 187      V09   Toán, tiếng Nhật, Vẽ mỹ thuật
# 188      V10   Toán, tiếng Pháp, Vẽ mỹ thuật
# 189      V11  Toán, tiếng Trung, Vẽ mỹ thuật
#
# [190 rows x 2 columns]

# %%
for index, row in df2.iterrows():
    khoi = row['Khoi thi'].strip().strip('\n').strip('\t')
    to_hop_mon = row['To hop mon'].strip().strip('\n').strip('\t')
    
    if isinstance(to_hop_mon, str):
        to_hop_mon = to_hop_mon.replace(',',';')
        if ';' in to_hop_mon:
            list_to_hop_mon = to_hop_mon.split(';')
        else:
            list_to_hop_mon = [to_hop_mon]
    else:
        list_to_hop_mon = list()
    list_to_hop_mon = [x.strip() for x in list_to_hop_mon]
    
    ins = {
        "Khoi": khoi,
        "To Hop Mon": list_to_hop_mon
    }
    
    khoithi.insert_one(ins)

# %%
df3 = pandas.read_csv('../CSV/Collection_Truong.csv')
df3
# Out:
#                              Ten Truong  Ma Truong  \
# 0   Đại học Công nghệ thông tin Gia Định   GIADINH
# 1                       Đại học Văn Lang       VLU
# 2                            Đại học FPT       FPT
# 3                        Đại học Hoa Sen    HOASEN
# 4                     Đại học Hùng Vương       HVU
# 5            Đại học Kinh tế - Tài chính       UEF
# 6            Đại học Ngoại Ngữ - Tin học    HUFLIT
# 7              Đại học Quốc tế Hồng Bàng       HIU
# 8                Đại học Quốc tế Sài Gòn       SIU
# 9                       Đại học Văn Hiến       VHU
# 10                      Đại Học An Giang       AGU
# 11                             Nhạc Viện   HCMCONS
# 12              Đại học An Ninh Nhân Dân       T47
# 13                     đại học bách khoa        BK
# 14        đại học  công nghiệp thực phẩm      HUFI
# 15                   đại học công nghiệp       IUH
# 16           đại học công nghệ thông tin       UIT
# ...

# %%
import math
for index, row in df3.iterrows():
    name = row['Ma Truong'].strip().strip('\n').strip('\t')
    
    if not isinstance(row['Ky tuc xa'] , str):
        kytucxa = None 
    else: 
        kytucxa = row['Ky tuc xa'] 
    if not isinstance(row['Hoc phi'] , str): 
        hocphi = None
    else:
        hocphi = row['Hoc phi'] 
    

    ins = {
        "Ky Tuc Xa": kytucxa,
        "Hoc Phi": hocphi
    }
    
    print(ins)
    
    truong.update_one({"Ma Truong": name}, {"$set": ins})
# Out:
# {'Ky Tuc Xa': None, 'Hoc Phi': 'http://www.giadinh.edu.vn'}
# {'Ky Tuc Xa': '160/63A-B Phan Huy Ích, phường 12, quận Gò Vấp', 'Hoc Phi': 'http://www.vanlanguni.edu.vn'}
# {'Ky Tuc Xa': ' Lầu 2, toà nhà Innovation, lô 24 - CVPM Quang Trung - P. Tân Chánh Hiệp, Quận 12, TP. HCM ', 'Hoc Phi': 'http://www.fpt.edu.vn'}
# {'Ky Tuc Xa': None, 'Hoc Phi': 'http://www.hoasen.edu.vn'}
# {'Ky Tuc Xa': None, 'Hoc Phi': 'http://www.hungvuong.edu.vn'}
# {'Ky Tuc Xa': None, 'Hoc Phi': 'http://www.uef.edu.vn'}
# {'Ky Tuc Xa': None, 'Hoc Phi': 'http://www.huflit.edu.vn'}
# {'Ky Tuc Xa': None, 'Hoc Phi': 'http://www.hbu.edu.vn'}
# {'Ky Tuc Xa': None, 'Hoc Phi': 'http://www.siu.edu.vn'}
# {'Ky Tuc Xa': '1004B Âu Cơ Q.TB', 'Hoc Phi': 'http://www.vhu.edu.vn'}
# {'Ky Tuc Xa': None, 'Hoc Phi': 'https://www.agu.edu.vn'}
# {'Ky Tuc Xa': None, 'Hoc Phi': 'https://hcmcons.vn'}
# {'Ky Tuc Xa': 'http://ktx.vnuhcm.edu.vn', 'Hoc Phi': None}
# ...
