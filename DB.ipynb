# %%
from pymongo import MongoClient
try:
    client = MongoClient('mongodb+srv://admin:G5mwPiDbMSZrVs2d@chatbottuvantuyensinh-acxk9.mongodb.net/test?retryWrites=true&w=majority')
    db = client['ChatbotTuVanTuyenSinh']
    col_diem_chuan = db['DiemChuan']
    col_khoi_thi = db['KhoiThi']
    col_truong = db['Truong']
    col_rating = db['PhanHoi']
except:
    print("ERROR IN DATABASE CONNECTION\n")

# %%
import re
def remove_vietnamese_accent(s):
#     s = s.decode('utf-8')
    s = re.sub(u'[àáạảãâầấậẩẫăằắặẳẵ]', 'a', s)
    s = re.sub(u'[ÀÁẠẢÃĂẰẮẶẲẴÂẦẤẬẨẪ]', 'A', s)
    s = re.sub(u'[èéẹẻẽêềếệểễ]', 'e', s)
    s = re.sub(u'[ÈÉẸẺẼÊỀẾỆỂỄ]', 'E', s)
    s = re.sub(u'[òóọỏõôồốộổỗơờớợởỡ]', 'o', s)
    s = re.sub(u'[ÒÓỌỎÕÔỒỐỘỔỖƠỜỚỢỞỠ]', 'O', s)
    s = re.sub(u'[ìíịỉĩ]', 'i', s)
    s = re.sub(u'[ÌÍỊỈĨ]', 'I', s)
    s = re.sub(u'[ùúụủũưừứựửữ]', 'u', s)
    s = re.sub(u'[ƯỪỨỰỬỮÙÚỤỦŨ]', 'U', s)
    s = re.sub(u'[ỳýỵỷỹ]', 'y', s)
    s = re.sub(u'[ỲÝỴỶỸ]', 'Y', s)
    s = re.sub(u'[Đ]', 'D', s)
    s = re.sub(u'[đ]', 'd', s)
#     return s.encode('utf-8')
    s = s.lower()
    s = re.sub("li", "ly", s)
    s = re.sub("ki", "ky", s)
    return s

# %%
from collections import defaultdict
MON_THI_2_KHOI_THI = defaultdict(lambda: 'Unknown')
for doc in col_khoi_thi.find():
    MON_THI_2_KHOI_THI[frozenset([remove_vietnamese_accent(x) for x in doc["To Hop Mon"]])] = doc["Khoi"]
    
# Chả biết sao có mấy khối khác mã mà lại có cùng môn thi
print(len(MON_THI_2_KHOI_THI.keys()))

def convertMonThi2KhoiThi(DanhSachMon):
    return MON_THI_2_KHOI_THI[frozenset([remove_vietnamese_accent(x) for x in DanhSachMon])]

print(convertMonThi2KhoiThi(["ngữ văn", "lich su", "Địa lý"]))
# Out:
# 181
# C00

# %%
def is_inside(a, listOfA):
    for b in listOfA:
        if remove_vietnamese_accent(b) == remove_vietnamese_accent(a):
            return True
    return False

# %%
def findDiemChuanByTruong(MaTruong, Nganh = None):
    DiemChuan = list()
    if Nganh:
        Nganh = Nganh.lower()
    for doc in col_diem_chuan.find():
        if MaTruong == doc["Ma Truong"]:
            if Nganh: 
                if Nganh == doc["Nganh"].lower():
                    DiemChuan.append(doc["Diem Chuan"])
            else:
                DiemChuan.append(doc["Diem Chuan"])
    return DiemChuan

findDiemChuanByTruong("HCMUE", "Giáo dục Chính trị")
# findDiemChuanByTruong("HCMUE", "hihi")
# Out:
# [19.75]

# %%
# có điểm thi + Môn thi + trường => biết đậu ngành gì trong trường đó
# Nếu không có mã trường thì tìm tất cả các ngành có thể đậu của tất cả trường
def findNganhByDiemThi(DiemThi, Khoi, MaTruong = None):
    TruongList = list()
    if isinstance(Khoi, list):
        Khoi = convertMonThi2KhoiThi(Khoi)
    for doc in col_diem_chuan.find():
        if Khoi in doc["Khoi"] and DiemThi >= doc["Diem Chuan"]:
            if MaTruong:
                if MaTruong == doc["Ma Truong"]:
                    TruongList.append(doc)
            else: TruongList.append(doc)
    return sorted(TruongList, key = lambda i: i["Diem Chuan"],reverse=True) 

# Nhập list môn hay mã khối đều OK
# findNganhByDiemThi(16.5, ["hoá học", "toan", "Sinh Học"], "NTU")
findNganhByDiemThi(25, "A00")
# Out:
# [{'_id': ObjectId('5d3d858ef6e7168c0a604e08'),
#   'Ma Truong': 'UAH',
#   'Ten Truong': 'Đại Học Ngoại Thương',
#   'Nganh': 'Kinh tế quản trị kinh doanh',
#   'Khoi': ['A00'],
#   'Diem Chuan': 24.25},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604ddd'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kinh tế quốc tế (Kinh tế đối ngoại)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 23.6},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604de5'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kinh doanh quốc tế',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 23.5},
#  {'_id': ObjectId('5d3d858ef6e7168c0a604e0a'),
#   'Ma Truong': 'UAH',
#   'Ten Truong': 'Đại Học Ngoại Thương',
#   'Nganh': 'Tài chính ngân hàng kế toán',
#   'Khoi': ['A00'],
#   'Diem Chuan': 23.5},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604e8c'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Khoa học máy tính ; Kỹ thuật Máy tính',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 23.25},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604bde'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Kỹ thuật phần mềm',
#   'Khoi': ['A00', 'A01', 'D06'],
#   'Diem Chuan': 23.2},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604dde'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kinh tế quốc tế (Kinh tế đối ngoại) (chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 23.15},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604de3'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'marketing',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 23.0},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604de6'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kinh doanh quốc tế (chất lượng cao )',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 23.0},
#  {'_id': ObjectId('5d3d8592f6e7168c0a604e6e'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Kinh doanh quốc tế',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 22.8},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fe0'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Kinh doanh quốc tế',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 22.8},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604de0'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Quản trị kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 22.6},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e77'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Ngoại thương',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 22.6},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fe9'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Ngoại thương',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 22.6},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604be5'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Công nghệ thông tin',
#   'Khoi': ['A00', 'A01', 'D13'],
#   'Diem Chuan': 22.5},
#  {'_id': ObjectId('5d3d858df6e7168c0a604de8'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Thương mại điện tử',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 22.5},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604bda'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Khoa học máy tính',
#   'Khoi': ['A00', 'A01', 'D02'],
#   'Diem Chuan': 22.4},
#  {'_id': ObjectId('5d3d8592f6e7168c0a604e70'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Marketing',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 22.4},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fe2'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Marketing',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 22.4},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604de4'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'marketing (chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 22.3},
#  {'_id': ObjectId('5d3d8577f6e7168c0a604be9'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'An toàn thông tin',
#   'Khoi': ['A00', 'A01', 'D17'],
#   'Diem Chuan': 22.25},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604e98'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật Hệ thống Công nghiệp ;logistics và Quản lý chuổi Cung ứng',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 22.25},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e79'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Quản trị khách sạn',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 22.2},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604feb'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Quản trị khách sạn',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 22.2},
#  {'_id': ObjectId('5d3d856ff6e7168c0a604b3d'),
#   'Ma Truong': 'IU',
#   'Ten Truong': 'Đại học Quốc Tế',
#   'Nganh': 'Logistics & Quản lý chuỗi cung ứng',
#   'Khoi': ['A00', 'A01', 'D00'],
#   'Diem Chuan': 22.0},
#  {'_id': ObjectId('5d3d856ff6e7168c0a604b3f'),
#   'Ma Truong': 'IU',
#   'Ten Truong': 'Đại học Quốc Tế',
#   'Nganh': 'Quản trị Kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 22.0},
#  {'_id': ObjectId('5d3d858df6e7168c0a604de7'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kinh doanh quốc tế (chất lượng cao bằng tiếng Anh)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 22.0},
#  {'_id': ObjectId('5d3d858df6e7168c0a604df1'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kiểm toán',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 22.0},
#  {'_id': ObjectId('5d3d858df6e7168c0a604dfb'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Luật thương mại quốc tế',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 22.0},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604e90'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật Hóa Học; Công Nghệ Thực Phẩm ; Công nghệ Sinh học',
#   'Khoi': ['A00', 'B00', 'D07'],
#   'Diem Chuan': 22.0},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604e96'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Quản lý Công nghiệp',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 22.0},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604ea0'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật Ô tô',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 22.0},
#  {'_id': ObjectId('5d3d8595f6e7168c0a604ea3'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Khoa học máy tính _ chất lượng cao',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 22.0},
#  {'_id': ObjectId('5d3d856df6e7168c0a604b03'),
#   'Ma Truong': 'HCMUE',
#   'Ten Truong': 'Đại Học Sư Phạm Thành Phố Hồ Chí Minh',
#   'Nganh': 'Sư phạm Hóa học',
#   'Khoi': ['A00', 'D07'],
#   'Diem Chuan': 21.8},
#  {'_id': ObjectId('5d3d858df6e7168c0a604dee'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kế toán',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 21.75},
#  {'_id': ObjectId('5d3d858df6e7168c0a604dfc'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Luật thương mại quốc tế (chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 21.75},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604ea1'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật Tàu thủy',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 21.75},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604be3'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Kỹ thuật máy tính',
#   'Khoi': ['A00', 'A01', 'D11'],
#   'Diem Chuan': 21.7},
#  {'_id': ObjectId('5d3d8592f6e7168c0a604e6f'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Kinh doanh thương mại',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.7},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fe1'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Kinh doanh thương mại',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.7},
#  {'_id': ObjectId('5d3d857ff6e7168c0a604cc2'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Quản trị kinh doanh\n(CN Quản trị nhân sự)',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 21.6},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e78'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Quản trị lữ hành',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.6},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fea'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Quản trị lữ hành',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.6},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604bdf'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Kỹ thuật phần mềm (Chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D07'],
#   'Diem Chuan': 21.5},
#  {'_id': ObjectId('5d3d857ef6e7168c0a604c98'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'logisitcs Và Quản lý Chuỗi cung ứng(Hệ Đại Trà)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 21.5},
#  {'_id': ObjectId('5d3d8580f6e7168c0a604cd7'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Dược học',
#   'Khoi': ['A00', 'B00', 'D07'],
#   'Diem Chuan': 21.5},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604dd8'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kinh tế (Kinh tế học)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 21.5},
#  {'_id': ObjectId('5d3d858df6e7168c0a604df9'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Luật kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 21.5},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604e8d'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật Điện; Kỹ thuật Điện tữ-Viễn thông ;\nKỹ thuật Điều khiển và tự động hóa',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 21.5},
#  {'_id': ObjectId('5d3d857df6e7168c0a604c81'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ Kỹ Thuật Cơ Điện Tử( hệ Đại TRà)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 21.4},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604de1'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Quản trị kinh doanh (chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 21.4},
#  {'_id': ObjectId('5d3d8592f6e7168c0a604e6d'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Quản trị kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.4},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e7a'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Quản trị sự kiện và dịch vụ giải trí',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.4},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fdf'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Quản trị kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.4},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fec'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Quản trị sự kiện và dịch vụ giải trí',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.4},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e81'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Tài chính quốc tế',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.3},
#  {'_id': ObjectId('5d3d85a4f6e7168c0a604ff3'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Tài chính quốc tế',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.3},
#  {'_id': ObjectId('5d3d8574f6e7168c0a604bac'),
#   'Ma Truong': 'SGU',
#   'Ten Truong': 'Đại Học Sài Gòn',
#   'Nganh': 'Sư phạm toán học',
#   'Khoi': ['A00'],
#   'Diem Chuan': 21.29},
#  {'_id': ObjectId('5d3d857df6e7168c0a604c91'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ Kỹ Thuật Điều Khiển Và Tự Động Hóa\n(Hệ Đại Trà)',
#   'Khoi': ['A00', 'B00', 'D07', 'D90'],
#   'Diem Chuan': 21.25},
#  {'_id': ObjectId('5d3d858df6e7168c0a604df3'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Hệ thống thông tin quản lý',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 21.25},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604e8e'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật Cơ Khí : Kỹ thuật Cơ điện tử ;',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 21.25},
#  {'_id': ObjectId('5d3d8575f6e7168c0a604bc8'),
#   'Ma Truong': 'UT',
#   'Ten Truong': 'Đại học giao thông vận tải',
#   'Nganh': 'Khai thác vận tải',
#   'Khoi': ['A00', 'A01', 'D90'],
#   'Diem Chuan': 21.2},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604bd9'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Thương mại điện  tử',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 21.2},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604bdc'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Mạng máy tính và truyền thông dữ liệu',
#   'Khoi': ['A00', 'A01', 'D04'],
#   'Diem Chuan': 21.2},
#  {'_id': ObjectId('5d3d858df6e7168c0a604de9'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Thương mại điện tử (chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 21.2},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e7c'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Quản trị hải quan - ngoại thương',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.2},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e85'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Thương mại điện tử',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.2},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fee'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Quản trị hải quan - ngoại thương',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.2},
#  {'_id': ObjectId('5d3d85a4f6e7168c0a604ff7'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Thương mại điện tử',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 21.2},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604be0'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Hệ thống thông tin',
#   'Khoi': ['A00', 'A01', 'D08'],
#   'Diem Chuan': 21.1},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f0a'),
#   'Ma Truong': 'NHU',
#   'Ten Truong': 'Trường Sĩ Quan Lục Quân 2',
#   'Nganh': 'Thí sinh Nam Quân khu 4 (Quảng Trị - Thừa Thiên Huế)',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 21.05},
#  {'_id': ObjectId('5d3d8577f6e7168c0a604beb'),
#   'Ma Truong': 'IUH',
#   'Ten Truong': 'Đại Học Công Nghiệp',
#   'Nganh': 'Luật kinh tế',
#   'Khoi': ['A00', 'D01', 'D96', 'C00'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d857ef6e7168c0a604c92'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ Kỹ Thuật Hóa Học( Hệ Đạ Trà)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8580f6e7168c0a604cc6'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Việt Nam học (CN Du\nlịch và Lữ hành)',
#   'Khoi': ['A00', 'C00', 'C01', 'D01'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8580f6e7168c0a604cc7'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Việt Nam học (CN Du\nlịch và Quản lí du lịch)',
#   'Khoi': ['A00', 'C00', 'C01', 'D01'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8580f6e7168c0a604cc8'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Kế toán',
#   'Khoi': ['A00', 'A01', 'C01', 'D0'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8585f6e7168c0a604d47'),
#   'Ma Truong': 'FPT',
#   'Ten Truong': 'Đại Học FPT',
#   'Nganh': 'Quản trị Kinh doanh\n - Quản trị Marketing\n - Quản trị Tài chính',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8585f6e7168c0a604d48'),
#   'Ma Truong': 'FPT',
#   'Ten Truong': 'Đại Học FPT',
#   'Nganh': 'Quản trị Khách sạn',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8585f6e7168c0a604d49'),
#   'Ma Truong': 'FPT',
#   'Ten Truong': 'Đại Học FPT',
#   'Nganh': 'Quản trị dịch vụ Du lịch & Lữ hành\xa0(Dự kiến)',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8585f6e7168c0a604d4a'),
#   'Ma Truong': 'FPT',
#   'Ten Truong': 'Đại Học FPT',
#   'Nganh': 'Kinh doanh quốc tế\n - Xuất nhập khẩu\n - Nghiệp vụ hải quan\n - Logistics và vận tải quốc tế',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8585f6e7168c0a604d4b'),
#   'Ma Truong': 'FPT',
#   'Ten Truong': 'Đại Học FPT',
#   'Nganh': 'Truyền thông đa phương tiện',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8585f6e7168c0a604d4c'),
#   'Ma Truong': 'FPT',
#   'Ten Truong': 'Đại Học FPT',
#   'Nganh': 'Thiết kế đồ hoạ\xa0\n - Thiết kế thời trang\n - Thiết kế nội thất\n - Đồ hoạ máy tính',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8585f6e7168c0a604d4d'),
#   'Ma Truong': 'FPT',
#   'Ten Truong': 'Đại Học FPT',
#   'Nganh': 'Ngôn ngữ Anh\xa0\n - Tiếng anh thương mại\n - Tiếng anh công nghệ thông tin',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8585f6e7168c0a604d4e'),
#   'Ma Truong': 'FPT',
#   'Ten Truong': 'Đại Học FPT',
#   'Nganh': 'Ngôn ngữ Nhật\xa0\n - Tiếng nhật thương mại\n - Tiếng nhật công nghệ thông tin',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8585f6e7168c0a604d4f'),
#   'Ma Truong': 'FPT',
#   'Ten Truong': 'Đại Học FPT',
#   'Nganh': 'Kỹ thuật phần mềm\xa0\n - Kỹ sư cầu nối Việt – Nhật\n - Hệ thống thông tin\n - Hệ thống nhúng',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8585f6e7168c0a604d50'),
#   'Ma Truong': 'FPT',
#   'Ten Truong': 'Đại Học FPT',
#   'Nganh': 'An toàn Thông tin\xa0\n - An ninh mạng\n - Quản trị an toàn thông tin\n - Ứng dụng an toàn thông tin',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8586f6e7168c0a604d51'),
#   'Ma Truong': 'FPT',
#   'Ten Truong': 'Đại Học FPT',
#   'Nganh': 'Khoa học Máy tính',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d858df6e7168c0a604df2'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kiểm toán ( chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d858df6e7168c0a604dfa'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Luật kinh doanh (chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8592f6e7168c0a604e62'),
#   'Ma Truong': 'UL',
#   'Ten Truong': 'Đại Học Luật TPHCM',
#   'Nganh': 'Quản trị - Luật',
#   'Khoi': ['A00'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8595f6e7168c0a604ea4'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật máy tính_ chất lượng cao',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8595f6e7168c0a604ea7'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật Cơ điện tử_ chất lượng cao',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8595f6e7168c0a604ea8'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật Hóa học_ chất lượng cao',
#   'Khoi': ['A00', 'B00', 'D07'],
#   'Diem Chuan': 21.0},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604bd8'),
#   'Ma Truong': 'UT',
#   'Ten Truong': 'Đại học giao thông vận tải',
#   'Nganh': 'Ngành khai thác vận tải _chất lượng cao',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 20.9},
#  {'_id': ObjectId('5d3d857ef6e7168c0a604c9f'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ Thực Phẩm ( Hệ Đại Trà)',
#   'Khoi': ['A00', 'B00', 'D07', 'D90'],
#   'Diem Chuan': 20.85},
#  {'_id': ObjectId('5d3d857df6e7168c0a604c83'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ Kỹ Thuật ô tô\n(Hệ Chất Lượng Cao Tiêng việt)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 20.8},
#  {'_id': ObjectId('5d3d8580f6e7168c0a604cc5'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Luật',
#   'Khoi': ['A00', 'A01', 'C00', 'D01'],
#   'Diem Chuan': 20.8},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fe3'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Tài chính – Ngân hàng',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 20.8},
#  {'_id': ObjectId('5d3d8580f6e7168c0a604cd4'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Kỹ thuật phần mềm',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 20.75},
#  {'_id': ObjectId('5d3d85a0f6e7168c0a604fa4'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Sư phạm Toán học',
#   'Khoi': ['A00', 'A01', 'D07', 'D08'],
#   'Diem Chuan': 20.75},
#  {'_id': ObjectId('5d3d85a1f6e7168c0a604fbe'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Luật, 3 chuyên ngành: - Luật hành chính; - Luật thương mại; - Luật tư pháp.',
#   'Khoi': ['A00', 'C00', 'D01', 'D03'],
#   'Diem Chuan': 20.75},
#  {'_id': ObjectId('5d3d8580f6e7168c0a604cc4'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Quản trị kinh doanh\n(CN Quản trị Nhà hàng - \nKhách sạn)',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 20.7},
#  {'_id': ObjectId('5d3d8592f6e7168c0a604e6c'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Kinh tế',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 20.7},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e73'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Kinh tế học ứng dụng',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 20.7},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fde'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Kinh tế',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 20.7},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fe5'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành kinh tế học úng dụng',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 20.7},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fe7'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Kinh tế chính trị',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 20.7},
#  {'_id': ObjectId('5d3d8574f6e7168c0a604baf'),
#   'Ma Truong': 'SGU',
#   'Ten Truong': 'Đại Học Sài Gòn',
#   'Nganh': 'Sư phạm hóa học',
#   'Khoi': ['A00'],
#   'Diem Chuan': 20.66},
#  {'_id': ObjectId('5d3d857df6e7168c0a604c8b'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công nghệ Kỹ thuật Điện - Điện tử(Hệ Đại Trà)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 20.65},
#  {'_id': ObjectId('5d3d8583f6e7168c0a604d0c'),
#   'Ma Truong': 'OU',
#   'Ten Truong': 'Đại Học Mở TPHCM',
#   'Nganh': 'Kinh doanh quốc tế',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 20.65},
#  {'_id': ObjectId('5d3d8572f6e7168c0a604b81'),
#   'Ma Truong': 'BUH',
#   'Ten Truong': 'Đại Học Ngân Hàng',
#   'Nganh': 'Kinh tế quốc tế',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 20.6},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604be8'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Công nghệ thông tin (Khoa học dữ liệu)',
#   'Khoi': ['A00', 'A01', 'D16'],
#   'Diem Chuan': 20.6},
#  {'_id': ObjectId('5d3d857df6e7168c0a604c84'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ Kỹ Thuật ô tô(Hệ Đại Trà)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 20.6},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604be6'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Công nghệ thông tin (Đào tạo tại phân hiệu ĐHQC-HCM tại bến tre)',
#   'Khoi': ['A00', 'A01', 'D14'],
#   'Diem Chuan': 20.5},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604dda'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kinh tế (Kinh tế và Quản lý Công)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 20.5},
#  {'_id': ObjectId('5d3d858df6e7168c0a604dea'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Tài chính - Ngân hàng',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 20.5},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604e8a'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Luật kinh doanh quốc tế',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 20.5},
#  {'_id': ObjectId('5d3d85a4f6e7168c0a604ffc'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Luật kinh doanh quốc tế',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 20.5},
#  {'_id': ObjectId('5d3d857df6e7168c0a604c90'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ Kỹ Thuật Điều Khiển Và Tự Động Hóa\n(Hệ Chất Lượng cao tiếng Việt)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 20.4},
#  {'_id': ObjectId('5d3d857ef6e7168c0a604c97'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Quản Lí Công nghệ (Hệ Đại Trà)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 20.4},
#  {'_id': ObjectId('5d3d858df6e7168c0a604def'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kế toán  (chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 20.4},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e72'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Kế toán',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 20.4},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fe4'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Kế toán',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 20.4},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fe6'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Kinh tế nông nghiệp',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 20.4},
#  {'_id': ObjectId('5d3d8574f6e7168c0a604bae'),
#   'Ma Truong': 'SGU',
#   'Ten Truong': 'Đại Học Sài Gòn',
#   'Nganh': 'Sư phạm vật lí',
#   'Khoi': ['A00'],
#   'Diem Chuan': 20.3},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e89'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Luật kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 20.3},
#  {'_id': ObjectId('5d3d85a4f6e7168c0a604ffb'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Luật kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 20.3},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604bdb'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Khoa học máy tính(Chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D03'],
#   'Diem Chuan': 20.25},
#  {'_id': ObjectId('5d3d857ff6e7168c0a604cc1'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Kinh doanh quốc tế',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 20.25},
#  {'_id': ObjectId('5d3d857ff6e7168c0a604cc3'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Quản trị kinh doanh\n(CN Quản trị Marketing)',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 20.25},
#  {'_id': ObjectId('5d3d8588f6e7168c0a604d7f'),
#   'Ma Truong': 'AGU',
#   'Ten Truong': 'Đại Học An Giang',
#   'Nganh': 'Giáo dục Tiểu học',
#   'Khoi': ['A00', 'A01', 'C00', 'D01'],
#   'Diem Chuan': 20.25},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604de2'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Quản trị kinh doanh (chất lượng cao bằng tiếng Anh)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 20.25},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f10'),
#   'Ma Truong': 'TDNU',
#   'Ten Truong': 'Đại học Trần Đại Nghĩa',
#   'Nganh': 'Thí sinh Nam miền nam',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 20.25},
#  {'_id': ObjectId('5d3d85a1f6e7168c0a604fb9'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Kinh doanh quốc tế',
#   'Khoi': ['A00', 'A01', 'C02', 'D01'],
#   'Diem Chuan': 20.25},
#  {'_id': ObjectId('5d3d857cf6e7168c0a604c66'),
#   'Ma Truong': 'UFM',
#   'Ten Truong': 'Đại học Tài Chính Marketing',
#   'Nganh': 'Quản trị khách sạn',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 20.2},
#  {'_id': ObjectId('5d3d857df6e7168c0a604c82'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ Kỹ Thuật ô tô\n(Hệ Chất Lượng Cao Tiêng Anh)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 20.2},
#  {'_id': ObjectId('5d3d857ef6e7168c0a604ca1'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ May ( Hệ Đại Trà)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 20.2},
#  {'_id': ObjectId('5d3d858df6e7168c0a604df4'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Hệ thống thông tin quản lý (chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 20.15},
#  {'_id': ObjectId('5d3d8577f6e7168c0a604bea'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'An toàn thông tin (Chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D18'],
#   'Diem Chuan': 20.1},
#  {'_id': ObjectId('5d3d8572f6e7168c0a604b80'),
#   'Ma Truong': 'BUH',
#   'Ten Truong': 'Đại Học Ngân Hàng',
#   'Nganh': 'Quản trị kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 20.0},
#  {'_id': ObjectId('5d3d8577f6e7168c0a604bed'),
#   'Ma Truong': 'IUH',
#   'Ten Truong': 'Đại Học Công Nghiệp',
#   'Nganh': 'Công nghệ kĩ thuật oto',
#   'Khoi': ['A00', 'A01', 'C01', 'D90'],
#   'Diem Chuan': 20.0},
#  {'_id': ObjectId('5d3d8585f6e7168c0a604d3e'),
#   'Ma Truong': 'HOASEN',
#   'Ten Truong': 'Đại Học Hoa Sen',
#   'Nganh': 'Quản trị công nghệ truyền thông',
#   'Khoi': ['A00', 'A01', 'D01/D03', 'D09'],
#   'Diem Chuan': 20.0},
#  {'_id': ObjectId('5d3d8592f6e7168c0a604e71'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Tài chính – Ngân hàng',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 20.0},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e84'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Hệ thống thông tin kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 20.0},
#  {'_id': ObjectId('5d3d8595f6e7168c0a604ea5'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật Điện - Điện tử_ chất lượng cao',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 20.0},
#  {'_id': ObjectId('5d3d8595f6e7168c0a604eaf'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật Ô tô_ chất lượng cao',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 20.0},
#  {'_id': ObjectId('5d3d85a1f6e7168c0a604fb7'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Quản trị kinh doanh',
#   'Khoi': ['A00', 'A01', 'C02', 'D01'],
#   'Diem Chuan': 20.0},
#  {'_id': ObjectId('5d3d85a4f6e7168c0a604ff6'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Hệ thống thông tin kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 20.0},
#  {'_id': ObjectId('5d3d857df6e7168c0a604c80'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ Kỹ Thuật Cở Điện Tử\n( hệ Chất Lượng Cao Tiếng Việt)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 19.9},
#  {'_id': ObjectId('5d3d857df6e7168c0a604c8f'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ Kỹ Thuật Điều Khiển Và Tự Động Hóa\n(Hệ Chất Lượng cao tiếng anh)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 19.9},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f0d'),
#   'Ma Truong': 'NHU',
#   'Ten Truong': 'Trường Sĩ Quan Lục Quân 2',
#   'Nganh': 'Thí sinh Nam Quân khu 9',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 19.9},
#  {'_id': ObjectId('5d3d8580f6e7168c0a604cd2'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Khoa học máy tính',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 19.75},
#  {'_id': ObjectId('5d3d858df6e7168c0a604deb'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Tài chính - Ngân hàng (chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 19.75},
#  {'_id': ObjectId('5d3d85a0f6e7168c0a604fa1'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Giáo dục Tiểu học',
#   'Khoi': ['A00', 'C01', 'D01', 'D03'],
#   'Diem Chuan': 19.75},
#  {'_id': ObjectId('5d3d85a0f6e7168c0a604fa7'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Sư phạm Hóa học',
#   'Khoi': ['A00', 'A01', 'A02', 'D29'],
#   'Diem Chuan': 19.75},
#  {'_id': ObjectId('5d3d85a1f6e7168c0a604fb8'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Marketing',
#   'Khoi': ['A00', 'A01', 'C02', 'D01'],
#   'Diem Chuan': 19.75},
#  {'_id': ObjectId('5d3d857cf6e7168c0a604c65'),
#   'Ma Truong': 'UFM',
#   'Ten Truong': 'Đại học Tài Chính Marketing',
#   'Nganh': 'Quản lí dịch vụ du lịch và lữ hành',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 19.7},
#  {'_id': ObjectId('5d3d857df6e7168c0a604c8e'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công nghệ Kỹ Thuật Điện Tử - Viễn Thông\n (Hệ Đại Trà)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 19.65},
#  {'_id': ObjectId('5d3d8570f6e7168c0a604b54'),
#   'Ma Truong': 'NLU',
#   'Ten Truong': 'Đại học Nông Lâm',
#   'Nganh': 'Thú Y',
#   'Khoi': ['A00', 'B00', 'D07', 'D08'],
#   'Diem Chuan': 19.6},
#  {'_id': ObjectId('5d3d8571f6e7168c0a604b5a'),
#   'Ma Truong': 'NLU',
#   'Ten Truong': 'Đại học Nông Lâm',
#   'Nganh': 'Thú Y',
#   'Khoi': ['A00', 'B00', 'D07', 'C08'],
#   'Diem Chuan': 19.6},
#  {'_id': ObjectId('5d3d8575f6e7168c0a604bc9'),
#   'Ma Truong': 'UT',
#   'Ten Truong': 'Đại học giao thông vận tải',
#   'Nganh': 'kinh tế vận tải',
#   'Khoi': ['A00', 'A01', 'D90'],
#   'Diem Chuan': 19.6},
#  {'_id': ObjectId('5d3d8580f6e7168c0a604cc9'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Tài chính - Ngân hàng',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 19.6},
#  {'_id': ObjectId('5d3d8572f6e7168c0a604b7f'),
#   'Ma Truong': 'BUH',
#   'Ten Truong': 'Đại Học Ngân Hàng',
#   'Nganh': 'kế toán',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 19.5},
#  {'_id': ObjectId('5d3d8574f6e7168c0a604bb8'),
#   'Ma Truong': 'UT',
#   'Ten Truong': 'Đại học giao thông vận tải',
#   'Nganh': 'Công nghệ thông tin',
#   'Khoi': ['A00', 'A01', 'D90'],
#   'Diem Chuan': 19.5},
#  {'_id': ObjectId('5d3d8578f6e7168c0a604c05'),
#   'Ma Truong': 'IUH',
#   'Ten Truong': 'Đại Học Công Nghiệp',
#   'Nganh': 'Kiểm toán',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 19.5},
#  {'_id': ObjectId('5d3d857af6e7168c0a604c45'),
#   'Ma Truong': 'UUSH',
#   'Ten Truong': 'Khoa Học Xã Hội và Nhân Văn',
#   'Nganh': 'Xã hội học',
#   'Khoi': ['A00', 'D01', 'D14'],
#   'Diem Chuan': 19.5},
#  {'_id': ObjectId('5d3d8583f6e7168c0a604d12'),
#   'Ma Truong': 'OU',
#   'Ten Truong': 'Đại Học Mở TPHCM',
#   'Nganh': 'Quản trị nhân lực',
#   'Khoi': ['A00', 'A01', 'C02', 'D01'],
#   'Diem Chuan': 19.5},
#  {'_id': ObjectId('5d3d8592f6e7168c0a604e65'),
#   'Ma Truong': 'UL',
#   'Ten Truong': 'Đại Học Luật TPHCM',
#   'Nganh': 'Luật',
#   'Khoi': ['A00', 'A01', 'D01', 'D03', 'D06'],
#   'Diem Chuan': 19.5},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604ea2'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật Hàng không',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 19.5},
#  {'_id': ObjectId('5d3d8595f6e7168c0a604eac'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Quản lý công nghiệp_ chất lượng cao',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 19.5},
#  {'_id': ObjectId('5d3d8598f6e7168c0a604eee'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Giáo dục tiểu học',
#   'Khoi': ['A00', 'A16', 'C00', 'D01'],
#   'Diem Chuan': 19.5},
#  {'_id': ObjectId('5d3d85a1f6e7168c0a604fbc'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Kế toán',
#   'Khoi': ['A00', 'A01', 'C02', 'D01'],
#   'Diem Chuan': 19.5},
#  {'_id': ObjectId('5d3d857cf6e7168c0a604c63'),
#   'Ma Truong': 'UFM',
#   'Ten Truong': 'Đại học Tài Chính Marketing',
#   'Nganh': 'Kế toán',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 19.4},
#  {'_id': ObjectId('5d3d857df6e7168c0a604c7f'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ Kỉ Thuật Cơ Điện Tử\n( hệ Chất Lượng Cao Tiếng Anh)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 19.4},
#  {'_id': ObjectId('5d3d857df6e7168c0a604c8a'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công nghệ Kỹ thuật Điện - Điện tử\n(Hệ Chất Lượng cao tiếng việt)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 19.4},
#  {'_id': ObjectId('5d3d8582f6e7168c0a604d0a'),
#   'Ma Truong': 'OU',
#   'Ten Truong': 'Đại Học Mở TPHCM',
#   'Nganh': 'Quản trị kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 19.4},
#  {'_id': ObjectId('5d3d857cf6e7168c0a604c67'),
#   'Ma Truong': 'UFM',
#   'Ten Truong': 'Đại học Tài Chính Marketing',
#   'Nganh': 'Quản lí nhà hàng và dịch vụ ăn uống',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 19.3},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e83'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Thống kê kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 19.3},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f0c'),
#   'Ma Truong': 'NHU',
#   'Ten Truong': 'Trường Sĩ Quan Lục Quân 2',
#   'Nganh': 'Thí sinh Nam Quân khu 7',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 19.3},
#  {'_id': ObjectId('5d3d85a4f6e7168c0a604ff5'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Thống kê kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 19.3},
#  {'_id': ObjectId('5d3d8580f6e7168c0a604cd3'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Mạng máy tính và \ntruyền thông dữ liệu',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 19.25},
#  {'_id': ObjectId('5d3d8583f6e7168c0a604d15'),
#   'Ma Truong': 'OU',
#   'Ten Truong': 'Đại Học Mở TPHCM',
#   'Nganh': 'Luật kinh tế',
#   'Khoi': ['A00', 'A01', 'C00', 'D01', 'D03', 'D05', 'D06'],
#   'Diem Chuan': 19.25},
#  {'_id': ObjectId('5d3d858df6e7168c0a604df0'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kế toán  (chất lượng cao bằng tiếng Anh)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 19.25},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604e95'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật địa chất : Kỹ thuật Dầu khí',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 19.25},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604e9d'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Cơ kỹ thuật',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 19.25},
#  {'_id': ObjectId('5d3d85a1f6e7168c0a604fba'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Kinh doanh thương mại',
#   'Khoi': ['A00', 'A01', 'C02', 'D01'],
#   'Diem Chuan': 19.25},
#  {'_id': ObjectId('5d3d85a1f6e7168c0a604fbb'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Tài chính - Ngân hàng',
#   'Khoi': ['A00', 'A01', 'C02', 'D01'],
#   'Diem Chuan': 19.25},
#  {'_id': ObjectId('5d3d857ef6e7168c0a604c9e'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Công Nghệ Thực Phẩm\n ( Hệ Chất lượng Cao Tiếng Việt)',
#   'Khoi': ['A00', 'B00', 'D07', 'D90'],
#   'Diem Chuan': 19.2},
#  {'_id': ObjectId('5d3d857ef6e7168c0a604ca6'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Quản Trị Nhà Hàng Và Dịch Vụ Ăn Uống\n (Hệ Đại Trà)',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 19.2},
#  {'_id': ObjectId('5d3d8585f6e7168c0a604d41'),
#   'Ma Truong': 'HOASEN',
#   'Ten Truong': 'Đại Học Hoa Sen',
#   'Nganh': 'Quản trị nhà hàng và dịch vụ ăn uống',
#   'Khoi': ['A00', 'A01', 'D01/D03', 'D09'],
#   'Diem Chuan': 19.2},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e82'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Toán tài chính',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 19.2},
#  {'_id': ObjectId('5d3d8571f6e7168c0a604b60'),
#   'Ma Truong': 'NLU',
#   'Ten Truong': 'Đại học Nông Lâm',
#   'Nganh': 'Công nghệ sinh học',
#   'Khoi': ['A00', 'A02', 'B00'],
#   'Diem Chuan': 19.15},
#  {'_id': ObjectId('5d3d8575f6e7168c0a604bb9'),
#   'Ma Truong': 'UT',
#   'Ten Truong': 'Đại học giao thông vận tải',
#   'Nganh': 'Kĩ thuật cơ khí',
#   'Khoi': ['A00', 'A01', 'D90'],
#   'Diem Chuan': 19.1},
#  {'_id': ObjectId('5d3d8575f6e7168c0a604bbd'),
#   'Ma Truong': 'UT',
#   'Ten Truong': 'Đại học giao thông vận tải',
#   'Nganh': 'Kĩ thuật điều khiển và tự động hóa',
#   'Khoi': ['A00', 'A01', 'D90'],
#   'Diem Chuan': 19.1},
#  {'_id': ObjectId('5d3d857ef6e7168c0a604c9b'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Kỹ Thuật Công Nghiệp(Hệ Đại Trà)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 19.1},
#  {'_id': ObjectId('5d3d8570f6e7168c0a604b42'),
#   'Ma Truong': 'IU',
#   'Ten Truong': 'Đại học Quốc Tế',
#   'Nganh': 'Công nghệ Thông Tin',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8570f6e7168c0a604b48'),
#   'Ma Truong': 'IU',
#   'Ten Truong': 'Đại học Quốc Tế',
#   'Nganh': 'Tài chính Ngân hàng',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8571f6e7168c0a604b66'),
#   'Ma Truong': 'NLU',
#   'Ten Truong': 'Đại học Nông Lâm',
#   'Nganh': 'Công nghệ kỹ thuật ô tô',
#   'Khoi': ['A00', 'A01', 'D07'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8572f6e7168c0a604b7e'),
#   'Ma Truong': 'BUH',
#   'Ten Truong': 'Đại Học Ngân Hàng',
#   'Nganh': 'Tài Chính Ngân Hàng',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604bd3'),
#   'Ma Truong': 'UT',
#   'Ten Truong': 'Đại học giao thông vận tải',
#   'Nganh': 'Ngành kỹ thuật cơ khí _chất lượng cao',
#   'Khoi': ['A00', 'A01', 'D90'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604be1'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Hệ thống thông tin (Chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D09'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8576f6e7168c0a604be7'),
#   'Ma Truong': 'UIT',
#   'Ten Truong': 'Đại học công nghệ thông tin',
#   'Nganh': 'Công nghệ thông tin (Chất lượng cao định hướng Nhật Bản)',
#   'Khoi': ['A00', 'A01', 'D15'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8577f6e7168c0a604bef'),
#   'Ma Truong': 'IUH',
#   'Ten Truong': 'Đại Học Công Nghiệp',
#   'Nganh': 'Công nghiệp kĩ thuật cơ khí',
#   'Khoi': ['A00', 'A01', 'C01', 'D90'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8577f6e7168c0a604bf0'),
#   'Ma Truong': 'IUH',
#   'Ten Truong': 'Đại Học Công Nghiệp',
#   'Nganh': 'Công nghệ kĩ thuật cơ điện tử',
#   'Khoi': ['A00', 'A01', 'C01', 'D90'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d857ef6e7168c0a604c9c'),
#   'Ma Truong': 'UTE',
#   'Ten Truong': 'Đại học Sư Phạm Kỹ Thuật',
#   'Nganh': 'Kỹ Thuật Y Sinh( Điện Tử Y Sinh) ( Hệ Đại Trà)',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8580f6e7168c0a604cd5'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Kỹ thuật hóa học',
#   'Khoi': ['A00', 'B00', 'C02', 'D07'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8580f6e7168c0a604cd6'),
#   'Ma Truong': 'TDTU',
#   'Ten Truong': 'Đại học Tôn Đức Thắng',
#   'Nganh': 'Công nghệ sinh học',
#   'Khoi': ['A00', 'B00', 'D08'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d858bf6e7168c0a604dcf'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại Học Kinh Tế -Tài Chính TPHCM',
#   'Nganh': 'Luật quốc tế',
#   'Khoi': ['A00', 'A01', 'D01', 'C00'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604dd4'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại Học Kinh Tế -Tài Chính TPHCM',
#   'Nganh': 'Quan hệ công chúng',
#   'Khoi': ['A00', 'A01', 'D01', 'C01'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604dd9'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kinh tế (Kinh tế học) (chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d858cf6e7168c0a604ddb'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Kinh tế (Kinh tế và Quản lý Công) (chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d858df6e7168c0a604df5'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Luật dân sự',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d858df6e7168c0a604df6'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Luật dân sự (chất lượng cao)',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d858df6e7168c0a604df7'),
#   'Ma Truong': 'UEL',
#   'Ten Truong': 'Đại học Kinh Tế_ Luật',
#   'Nganh': 'Luật Tài chính - Ngân hàng',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8592f6e7168c0a604e67'),
#   'Ma Truong': 'UL',
#   'Ten Truong': 'Đại Học Luật TPHCM',
#   'Nganh': 'Quản trị kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01', 'D03', 'D06', 'D84', 'D87', 'D88'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e74'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Kinh tế nông nghiệp',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e75'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Kinh tế chính trị',
#   'Khoi': ['A00', 'A01', 'D01', 'D96'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e80'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Đầu tư tài chính',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8593f6e7168c0a604e87'),
#   'Ma Truong': 'UEH',
#   'Ten Truong': 'Đại học Kinh Tế Tài chính',
#   'Nganh': 'Công nghệ phần mềm',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8595f6e7168c0a604ea6'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Kỹ thuật Cơ khí_ chất lượng cao',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8595f6e7168c0a604eaa'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Công nghệ Thực phẩm_ chất lượng cao',
#   'Khoi': ['A00', 'B00', 'D07'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d85a1f6e7168c0a604fb2'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Kinh tế',
#   'Khoi': ['A00', 'A01', 'C02', 'D01'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d85a3f6e7168c0a604fe8'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Quản trị bệnh viện',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d85a4f6e7168c0a604ff2'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Đầu tư tài chính',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d85a4f6e7168c0a604ff4'),
#   'Ma Truong': 'UEF',
#   'Ten Truong': 'Đại học Kinh Tế',
#   'Nganh': 'Chuyên ngành Toán tài chính',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 19.0},
# ...
#   'Nganh': 'Quản trị kinh doanh',
#   'Khoi': ['A00', 'A01', 'C03', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8597f6e7168c0a604ee6'),
#   'Ma Truong': 'BETU',
#   'Ten Truong': 'Đại Học Kinh Tế Bình Dương',
#   'Nganh': 'Tài chính – Ngân hàng',
#   'Khoi': ['A00', 'A01', 'C03', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8597f6e7168c0a604ee7'),
#   'Ma Truong': 'BETU',
#   'Ten Truong': 'Đại Học Kinh Tế Bình Dương',
#   'Nganh': 'Kế toán',
#   'Khoi': ['A00', 'A01', 'C03', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8597f6e7168c0a604ee8'),
#   'Ma Truong': 'BETU',
#   'Ten Truong': 'Đại Học Kinh Tế Bình Dương',
#   'Nganh': 'Quản trị văn phòng',
#   'Khoi': ['A00', 'A01', 'C03', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8598f6e7168c0a604ee9'),
#   'Ma Truong': 'BETU',
#   'Ten Truong': 'Đại Học Kinh Tế Bình Dương',
#   'Nganh': 'Công nghệ thông tin',
#   'Khoi': ['A00', 'A01', 'C03', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8598f6e7168c0a604eea'),
#   'Ma Truong': 'BETU',
#   'Ten Truong': 'Đại Học Kinh Tế Bình Dương',
#   'Nganh': 'Công nghệ kỹ thuật điện, điện tử',
#   'Khoi': ['A00', 'A01', 'C01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8598f6e7168c0a604eeb'),
#   'Ma Truong': 'BETU',
#   'Ten Truong': 'Đại Học Kinh Tế Bình Dương',
#   'Nganh': 'Kỹ thuật xây dựng công trình giao thông',
#   'Khoi': ['A00', 'A01', 'C01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8598f6e7168c0a604efb'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Sinh học ứng dụng',
#   'Khoi': ['A00', 'A02', 'B00', 'B05'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8598f6e7168c0a604efc'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Vật lí học',
#   'Khoi': ['A00', 'A01', 'A17', 'C01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8598f6e7168c0a604efd'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Hóa học',
#   'Khoi': ['A00', 'A16', 'B00', 'D07'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8598f6e7168c0a604efe'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Khoa học môi trường',
#   'Khoi': ['A00', 'B00', 'B05', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8598f6e7168c0a604eff'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Toán học',
#   'Khoi': ['A00', 'A01', 'A16', 'D07'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8598f6e7168c0a604f00'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Kỹ thuật phần mền-\nCông nghẹ thông tin',
#   'Khoi': ['A00', 'A01', 'C01', 'D90'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f01'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Hệ thông thông tin- \nCông nghệ thông tin',
#   'Khoi': ['A00', 'A01', 'C01', 'D90'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f02'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Quản lí công nghiệp',
#   'Khoi': ['A00', 'A01', 'A16', 'C01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f03'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Kỹ thuật Điện',
#   'Khoi': ['A00', 'A01', 'C01', 'D90'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f04'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Kiến trúc',
#   'Khoi': ['A00', 'A16', 'V00', 'V01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f05'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Quy hoạch Vùng và Đô thị - Quản lý Đô thị',
#   'Khoi': ['A00', 'A16', 'V00', 'V01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f06'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Kỹ thuật xây dựng',
#   'Khoi': ['A00', 'A01', 'C01', 'D90'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f08'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Quản lý tài nguyên và Môi trường',
#   'Khoi': ['A00', 'B00', 'B05', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f09'),
#   'Ma Truong': 'TDMU',
#   'Ten Truong': 'Đại học Thủ Dầu Một',
#   'Nganh': 'Quản lý Đất đai',
#   'Khoi': ['A00', 'B00', 'B05', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f13'),
#   'Ma Truong': 'VHU',
#   'Ten Truong': 'Đại Học Văn Hiến',
#   'Nganh': 'Quản trị kinh doang',
#   'Khoi': ['A00', 'A01', 'D01: C04'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8599f6e7168c0a604f16'),
#   'Ma Truong': 'VHU',
#   'Ten Truong': 'Đại Học Văn Hiến',
#   'Nganh': 'Xã hội học',
#   'Khoi': ['A00', 'C00', 'D01', 'C04'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859bf6e7168c0a604f37'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Kinh tế',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859bf6e7168c0a604f3a'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Quản trị kinh doanh',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859bf6e7168c0a604f3b'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Tài chính – Ngân hàng',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859bf6e7168c0a604f3c'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Kế toán',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859bf6e7168c0a604f3d'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Luật kinh tế',
#   'Khoi': ['A00', 'A01', 'C00', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859bf6e7168c0a604f40'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Công nghệ thông tin',
#   'Khoi': ['A00', 'A01', 'D01', 'D07'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859bf6e7168c0a604f41'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Công nghệ kỹ thuật công trình xây dựng',
#   'Khoi': ['A00', 'A01', 'D01', 'V00'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859bf6e7168c0a604f42'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Công nghệ kỹ thuật cơ khí',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859bf6e7168c0a604f44'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Công nghệ kỹ thuật điện, điện tử',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859cf6e7168c0a604f45'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Công nghệ kỹ thuật điện tử - viễn thông',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859cf6e7168c0a604f46'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Công nghệ kỹ thuật điều khiển và tự động hóa',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859cf6e7168c0a604f48'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Công nghệ thực phẩm',
#   'Khoi': ['A00', 'B00', 'C02', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859df6e7168c0a604f63'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Kế toán',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859df6e7168c0a604f64'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Quản trị Kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859ef6e7168c0a604f6f'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Công nghệ Thực phẩm',
#   'Khoi': ['A00', 'A01', 'B00', 'D08'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859ef6e7168c0a604f7b'),
#   'Ma Truong': 'BDU',
#   'Ten Truong': 'Đại học Bình Dương',
#   'Nganh': 'Công nghệ sinh học',
#   'Khoi': ['A00', 'A01', 'B00', 'D01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859ef6e7168c0a604f7e'),
#   'Ma Truong': 'BDU',
#   'Ten Truong': 'Đại học Bình Dương',
#   'Nganh': 'Công nghệ kỹ thuật công trình xây dựng',
#   'Khoi': ['A00', 'A01', 'V00', 'V01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d859ff6e7168c0a604f7f'),
#   'Ma Truong': 'BDU',
#   'Ten Truong': 'Đại học Bình Dương',
#   'Nganh': 'Kiến trúc',
#   'Khoi': ['A00', 'A09', 'V00', 'V01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d85a2f6e7168c0a604fd2'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Kỹ thuật vật liệu',
#   'Khoi': ['A00', 'A01', 'B00', 'D07'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d85a2f6e7168c0a604fd3'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Kỹ thuật môi trường',
#   'Khoi': ['A00', 'A01', 'B00', 'D07'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d85a2f6e7168c0a604fd4'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Vật lý kỹ thuật',
#   'Khoi': ['A00', 'A01', 'A02'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d85a2f6e7168c0a604fd9'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Kỹ thuật xây dựng công trình thủy',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d85a2f6e7168c0a604fda'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Kỹ thuật xây dựng công trình giao thông',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d85a2f6e7168c0a604fdb'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Kỹ thuật tài nguyên nước',
#   'Khoi': ['A00', 'A01', 'D07'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d85a2f6e7168c0a604fdc'),
#   'Ma Truong': 'CTU',
#   'Ten Truong': 'Đại học Cần Thơ',
#   'Nganh': 'Khoa học đất',
#   'Khoi': ['A00', 'B00', 'D07', 'D08'],
#   'Diem Chuan': 14.0},
#  {'_id': ObjectId('5d3d8595f6e7168c0a604eb7'),
#   'Ma Truong': 'STU',
#   'Ten Truong': 'Đại Học Công Nghệ Sài Gòn',
#   'Nganh': 'Công nghệ kỹ thuật cơ điện tử',
#   'Khoi': ['D01', 'A00', 'A01', 'D07'],
#   'Diem Chuan': 13.5},
#  {'_id': ObjectId('5d3d8595f6e7168c0a604eb8'),
#   'Ma Truong': 'STU',
#   'Ten Truong': 'Đại Học Công Nghệ Sài Gòn',
#   'Nganh': 'Công nghệ kỹ thuật điện, điện tử',
#   'Khoi': ['D01', 'A00', 'A01', 'D07'],
#   'Diem Chuan': 13.5},
#  {'_id': ObjectId('5d3d8596f6e7168c0a604eb9'),
#   'Ma Truong': 'STU',
#   'Ten Truong': 'Đại Học Công Nghệ Sài Gòn',
#   'Nganh': 'Công nghệ kỹ thuật điện tử viễn thông',
#   'Khoi': ['D01', 'A00', 'A01', 'D07'],
#   'Diem Chuan': 13.5},
#  {'_id': ObjectId('5d3d8596f6e7168c0a604ebd'),
#   'Ma Truong': 'STU',
#   'Ten Truong': 'Đại Học Công Nghệ Sài Gòn',
#   'Nganh': 'Kỹ thuật xây dựng',
#   'Khoi': ['D01', 'A00', 'A01', 'D07'],
#   'Diem Chuan': 13.5},
#  {'_id': ObjectId('5d3d8596f6e7168c0a604ebe'),
#   'Ma Truong': 'STU',
#   'Ten Truong': 'Đại Học Công Nghệ Sài Gòn',
#   'Nganh': 'Thiết kế công nghiệp',
#   'Khoi': ['D01', 'A00', 'A01', 'H06'],
#   'Diem Chuan': 13.5},
#  {'_id': ObjectId('5d3d859ef6e7168c0a604f77'),
#   'Ma Truong': 'BDU',
#   'Ten Truong': 'Đại học Bình Dương',
#   'Nganh': 'Quản trị kinh doanh',
#   'Khoi': ['A00', 'A01', 'C00', 'D01'],
#   'Diem Chuan': 13.5},
#  {'_id': ObjectId('5d3d859ef6e7168c0a604f78'),
#   'Ma Truong': 'BDU',
#   'Ten Truong': 'Đại học Bình Dương',
#   'Nganh': 'Kế toán',
#   'Khoi': ['A00', 'A01', 'C00', 'D01'],
#   'Diem Chuan': 13.5},
#  {'_id': ObjectId('5d3d859ef6e7168c0a604f7a'),
#   'Ma Truong': 'BDU',
#   'Ten Truong': 'Đại học Bình Dương',
#   'Nganh': 'Luật kinh tế',
#   'Khoi': ['A00', 'A01', 'C00', 'D01'],
#   'Diem Chuan': 13.5},
#  {'_id': ObjectId('5d3d859ef6e7168c0a604f7c'),
#   'Ma Truong': 'BDU',
#   'Ten Truong': 'Đại học Bình Dương',
#   'Nganh': 'Công nghệ thông tin',
#   'Khoi': ['A00', 'A01', 'A02', 'D01'],
#   'Diem Chuan': 13.5},
#  {'_id': ObjectId('5d3d859ef6e7168c0a604f7d'),
#   'Ma Truong': 'BDU',
#   'Ten Truong': 'Đại học Bình Dương',
#   'Nganh': 'Công nghệ kỹ thuật điện - điện tử',
#   'Khoi': ['A00', 'A01', 'A02', 'D01'],
#   'Diem Chuan': 13.5},
#  {'_id': ObjectId('5d3d859df6e7168c0a604f65'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Tài chính ngân hàng',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 13.0},
#  {'_id': ObjectId('5d3d859df6e7168c0a604f66'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Kinh tế',
#   'Khoi': ['A00', 'A01', 'D01', 'D90'],
#   'Diem Chuan': 13.0},
#  {'_id': ObjectId('5d3d859df6e7168c0a604f67'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Công nghệ Sinh học',
#   'Khoi': ['A00', 'A01', 'B00', 'D08'],
#   'Diem Chuan': 13.0},
#  {'_id': ObjectId('5d3d859df6e7168c0a604f68'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Toán ứng dụng',
#   'Khoi': ['A00', 'A01', 'D07', 'D90'],
#   'Diem Chuan': 13.0},
#  {'_id': ObjectId('5d3d859df6e7168c0a604f69'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Công nghệ Thông tin',
#   'Khoi': ['A00', 'A01', 'D07', 'D90'],
#   'Diem Chuan': 13.0},
#  {'_id': ObjectId('5d3d859df6e7168c0a604f6a'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Hệ thống thông tin',
#   'Khoi': ['A00', 'A01', 'D07', 'D90'],
#   'Diem Chuan': 13.0},
#  {'_id': ObjectId('5d3d859df6e7168c0a604f6b'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Công nghệ Kỹ thuật Xây dựng',
#   'Khoi': ['A00', 'A01', 'D07', 'D90'],
#   'Diem Chuan': 13.0},
#  {'_id': ObjectId('5d3d859df6e7168c0a604f6c'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Công nghệ Kỹ thuật Cơ khí',
#   'Khoi': ['A00', 'A01', 'D07', 'D90'],
#   'Diem Chuan': 13.0},
#  {'_id': ObjectId('5d3d859ef6e7168c0a604f6d'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Công nghệ kỹ thuật điều khiển và tự động hóa',
#   'Khoi': ['A00', 'A01', 'D07', 'D90'],
#   'Diem Chuan': 13.0},
#  {'_id': ObjectId('5d3d859ef6e7168c0a604f6e'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Công nghệ kỹ thuật cơ điện tử',
#   'Khoi': ['A00', 'A01', 'D07', 'D90'],
#   'Diem Chuan': 13.0},
#  {'_id': ObjectId('5d3d859ef6e7168c0a604f70'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Nuôi trồng thủy sản',
#   'Khoi': ['A00', 'A01', 'B00', 'D08'],
#   'Diem Chuan': 13.0},
#  {'_id': ObjectId('5d3d859ef6e7168c0a604f71'),
#   'Ma Truong': 'TGU',
#   'Ten Truong': 'Trường Đại Học Tiền Giang',
#   'Nganh': 'Khoa học cây trồng',
#   'Khoi': ['A00', 'A01', 'B00', 'D08'],
#   'Diem Chuan': 13.0},
#  {'_id': ObjectId('5d3d8589f6e7168c0a604da8'),
#   'Ma Truong': 'AGU',
#   'Ten Truong': 'Đại Học An Giang',
#   'Nganh': 'Kế toán',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 10.0},
#  {'_id': ObjectId('5d3d8589f6e7168c0a604da9'),
#   'Ma Truong': 'AGU',
#   'Ten Truong': 'Đại Học An Giang',
#   'Nganh': 'Quản trị kinh doanh',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 10.0},
#  {'_id': ObjectId('5d3d8589f6e7168c0a604daa'),
#   'Ma Truong': 'AGU',
#   'Ten Truong': 'Đại Học An Giang',
#   'Nganh': 'Phát triển Nông thôn',
#   'Khoi': ['A00', 'A01', 'B00'],
#   'Diem Chuan': 10.0},
#  {'_id': ObjectId('5d3d8589f6e7168c0a604dab'),
#   'Ma Truong': 'AGU',
#   'Ten Truong': 'Đại Học An Giang',
#   'Nganh': 'Bảo vệ Thực vật',
#   'Khoi': ['A00', 'A01', 'B00'],
#   'Diem Chuan': 10.0},
#  {'_id': ObjectId('5d3d8589f6e7168c0a604dac'),
#   'Ma Truong': 'AGU',
#   'Ten Truong': 'Đại Học An Giang',
#   'Nganh': 'Công nghệ thực phẩm',
#   'Khoi': ['A00', 'A01', 'B00'],
#   'Diem Chuan': 10.0},
#  {'_id': ObjectId('5d3d858af6e7168c0a604dad'),
#   'Ma Truong': 'AGU',
#   'Ten Truong': 'Đại Học An Giang',
#   'Nganh': 'Công nghệ thông tin',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 10.0},
#  {'_id': ObjectId('5d3d858af6e7168c0a604daf'),
#   'Ma Truong': 'AGU',
#   'Ten Truong': 'Đại Học An Giang',
#   'Nganh': 'Dịch vụ thú y',
#   'Khoi': ['A00', 'A01', 'B00'],
#   'Diem Chuan': 10.0},
#  {'_id': ObjectId('5d3d858af6e7168c0a604db0'),
#   'Ma Truong': 'AGU',
#   'Ten Truong': 'Đại Học An Giang',
#   'Nganh': 'Thiết kế trang web',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 10.0}]

# %%
def common_member(a, b): 
    a_set = set(a) 
    b_set = set(b) 
    if (a_set & b_set): 
        return True 
    else: 
        return False

# %%
# có điểm thi + Môn thi + trường => biết đậu ngành gì trong trường đó
# Nếu không có mã trường thì tìm tất cả các ngành có thể đậu của tất cả trường
def findNganhByDiemThiKhoiTruong(DiemThi, Khoi, MaTruong):
    TruongSet = set()
    TruongList = list()
    DiemThiSet = set()
    KhoiSet = set()
    MaTruongSet = set()
        
    for doc in col_diem_chuan.find():
        TruongList.append(doc)
        TruongSet.add(doc['_id'])
        if DiemThi is not None and DiemThi >= doc["Diem Chuan"]:
            DiemThiSet.add(doc['_id'])
        if Khoi is not None and common_member(Khoi, doc["Khoi"]):
            KhoiSet.add(doc['_id'])
        if MaTruong is not None and doc["Ma Truong"] in MaTruong:
            MaTruongSet.add(doc['_id'])        
            
    if len(DiemThiSet) == 0: 
        DiemThiSet = TruongSet
    if len(KhoiSet) == 0: 
        KhoiSet = TruongSet
    if len(MaTruongSet) == 0: 
        MaTruongSet = TruongSet
        
    TruongSet = DiemThiSet.intersection(KhoiSet).intersection(MaTruongSet)
    
    TruongList[:] = [d for d in TruongList if d['_id'] in TruongSet]

    return sorted(TruongList, key = lambda i: i["Diem Chuan"],reverse=True) 

# Nhập list môn hay mã khối đều OK
# findNganhByDiemThi(16.5, ["hoá học", "toan", "Sinh Học"], "NTU")
findNganhByDiemThiKhoiTruong(25.5, ['A02', 'B01'], ["BK"])
# Out:
# []

# %%
def findDiemChuanByTruongNganh(MaTruong, Nganh):
    DiemThiSet = set()
    DiemThiList = list()
    MaTruongSet = set()
    NganhSet = set()
    
    for doc in col_diem_chuan.find():
        DiemThiList.append(doc)
        DiemThiSet.add(doc['_id'])
        
        if MaTruong is not None and doc["Ma Truong"] in MaTruong:
            MaTruongSet.add(doc['_id'])        
        if Nganh is not None and is_inside(doc["Nganh"], Nganh):
            NganhSet.add(doc['_id'])        
            
    if len(NganhSet) == 0: 
        NganhSet = DiemThiSet
    if len(MaTruongSet) == 0: 
        MaTruongSet = DiemThiSet
        
    DiemThiSet = MaTruongSet.intersection(NganhSet)
    
    DiemThiList[:] = [d for d in DiemThiList if d['_id'] in DiemThiSet]
    
    return DiemThiList

findDiemChuanByTruongNganh(["HCMUE", "BK"], ["Giáo dục Chính trị", "Khoa học máy tính ; Kỹ thuật Máy tính"])
# findDiemChuanByTruong("HCMUE", "hihi")
# Out:
# [{'_id': ObjectId('5d3d856df6e7168c0a604aff'),
#   'Ma Truong': 'HCMUE',
#   'Ten Truong': 'Đại Học Sư Phạm Thành Phố Hồ Chí Minh',
#   'Nganh': 'Giáo dục Chính trị',
#   'Khoi': ['C00', 'D01'],
#   'Diem Chuan': 19.75},
#  {'_id': ObjectId('5d3d8594f6e7168c0a604e8c'),
#   'Ma Truong': 'BK',
#   'Ten Truong': 'Đại học Bách Khoa',
#   'Nganh': 'Khoa học máy tính ; Kỹ thuật Máy tính',
#   'Khoi': ['A00', 'A01'],
#   'Diem Chuan': 23.25}]

# %%
# có điểm thi + Môn thi + trường => biết đậu ngành gì trong trường đó
# Nếu không có mã trường thì tìm tất cả các ngành có thể đậu của tất cả trường
def findTruongByDiemThiKhoiNganh(DiemThi, Khoi, NganhHoc):
    TruongSet = set()
    TruongList = list()
    DiemThiSet = set()
    KhoiSet = set()
    NganhSet = set()
        
    for doc in col_diem_chuan.find():
        TruongList.append(doc)
        TruongSet.add(doc['_id'])
        if DiemThi is not None and DiemThi >= doc["Diem Chuan"]:
            DiemThiSet.add(doc['_id'])
        if Khoi is not None and common_member(Khoi, doc["Khoi"]):
            KhoiSet.add(doc['_id'])
        if NganhHoc is not None and is_inside(doc["Nganh"], NganhHoc):
            NganhSet.add(doc['_id'])        
            
    if len(DiemThiSet) == 0: 
        DiemThiSet = TruongSet
    if len(KhoiSet) == 0: 
        KhoiSet = TruongSet
    if len(NganhSet) == 0: 
        NganhSet = NganhSet
        
    TruongSet = DiemThiSet.intersection(KhoiSet).intersection(NganhSet)
    
    TruongList[:] = [d for d in TruongList if d['_id'] in TruongSet]

    return sorted(TruongList, key = lambda i: i["Diem Chuan"],reverse=True) 

# Nhập list môn hay mã khối đều OK
# findNganhByDiemThi(16.5, ["hoá học", "toan", "Sinh Học"], "NTU")
findTruongByDiemThiKhoiNganh(30, [], ['Công nghệ kĩ thuật ô tô'])
# Out:
# [{'_id': ObjectId('5d3d8571f6e7168c0a604b66'),
#   'Ma Truong': 'NLU',
#   'Ten Truong': 'Đại học Nông Lâm',
#   'Nganh': 'Công nghệ kỹ thuật ô tô',
#   'Khoi': ['A00', 'A01', 'D07'],
#   'Diem Chuan': 19.0},
#  {'_id': ObjectId('5d3d8596f6e7168c0a604eca'),
#   'Ma Truong': 'HUTECH',
#   'Ten Truong': 'Đại học Công Nghệ',
#   'Nganh': 'Công nghệ kỹ thuật ô tô',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 16.0},
#  {'_id': ObjectId('5d3d859cf6e7168c0a604f55'),
#   'Ma Truong': 'NCTU',
#   'Ten Truong': 'Đại học Nam Cần Thơ',
#   'Nganh': 'Công nghệ kỹ thuật ô tô',
#   'Khoi': ['A00', 'A01', 'D01'],
#   'Diem Chuan': 15.5},
#  {'_id': ObjectId('5d3d859bf6e7168c0a604f43'),
#   'Ma Truong': 'LHU',
#   'Ten Truong': 'ĐH Lạc Hồng',
#   'Nganh': 'Công nghệ kỹ thuật ô tô',
#   'Khoi': ['A00', 'A01', 'C01', 'D01'],
#   'Diem Chuan': 15.0}]

# %%
def findDiemChuanByTruongNganh(MaTruong, Nganh):
    DiemThiSet = set()
    DiemThiList = list()
    MaTruongSet = set()
    NganhSet = set()
    
    for doc in col_diem_chuan.find():
        DiemThiList.append(doc)
        DiemThiSet.add(doc['_id'])
        
        if MaTruong is not None and doc["Ma Truong"] in MaTruong:
            MaTruongSet.add(doc['_id'])        
        if Nganh is not None and is_inside(doc["Nganh"], Nganh):
            NganhSet.add(doc['_id'])        
            
    if len(NganhSet) == 0: 
        NganhSet = DiemThiSet
    if len(MaTruongSet) == 0: 
        MaTruongSet = DiemThiSet
        
    DiemThiSet = MaTruongSet.intersection(NganhSet)
    
    DiemThiList[:] = [d for d in DiemThiList if d['_id'] in DiemThiSet]
    
    return DiemThiList

# %%
def findKhoiThiByTruongNganh(MaTruong, Nganh):
    return findDiemChuanByTruongNganh(MaTruong, Nganh)

# %%
def findHocPhiByTruong(Truong):
    returnHocPhi = None
    for doc in col_truong.find():
        if doc["Ma Truong"] == Truong:
            returnHocPhi = doc["Hoc Phi"]
    return returnHocPhi

# %%
def findKyTucXaByTruong(Truong):
    returnKyTucXa = None
    for doc in col_truong.find():
        if doc["Ma Truong"] == Truong:
            returnKyTucXa = doc["Ky Tuc Xa"]
    return returnKyTucXa

# %%
def findLoaiHinhByTruong(Truong):
    returnLoaiHinh = None
    for doc in col_truong.find():
        if doc["Ma Truong"] == Truong:
            returnLoaiHinh = doc["isCongLap"]
    return returnLoaiHinh

# %%
def findDiaChiByTruong(Truong):
    returnDiaChi = None
    for doc in col_truong.find():
        if doc["Ma Truong"] == Truong:
            returnDiaChi = doc["Dia Chi"]
    return returnDiaChi

# %%
def saveRating(ratingToSave):
    return col_rating.insert_one(ratingToSave)
