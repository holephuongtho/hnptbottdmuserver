# %%
import pymongo
import pandas

# %%
df = pandas.read_csv('../CSV/ChuanHoaDuLieuTruong.csv')
df
# Out:
#                     input output
# 0                   ĐH BK     BK
# 1            ĐH Bách Khoa     BK
# 2            ĐH Bach Khoa     BK
# 3              Đại học BK     BK
# 4       Đại học Bách khoa     BK
# ..                    ...    ...
# 304                ĐHCNSG    STU
# 305               ĐH CNSG    STU
# 306                   STU    STU
# 307  Đại học Công Nghệ SG    STU
# 308       ĐH Công Nghệ SG    STU
#
# [309 rows x 2 columns]

# %%
for index, row in df.iterrows():
    print('\'' + row['input'] + '\'' + ':' + '\'' + row['output'] + '\',')
# Out:
# 'ĐH BK':'BK',
# 'ĐH Bách Khoa':'BK',
# 'ĐH Bach Khoa':'BK',
# 'Đại học BK':'BK',
# 'Đại học Bách khoa':'BK',
# 'Bách Khoa':'BK',
# 'BK':'BK',
# 'ĐH Công Nghệ Thông Tin Gia Định':'GIADINH',
# 'ĐH CNTT Gia Định':'GIADINH',
# 'ĐH Gia Định':'GIADINH',
# 'Đại học Công Nghệ Thông Tin Gia Định':'GIADINH',
# 'Đại học CNTT Gia Định':'GIADINH',
# 'Đại học Gia Định':'GIADINH',
# 'Gia Định':'GIADINH',
# 'ĐH Văn Lang':'VLU',
# 'Đại học Văn Lang':'VLU',
# 'Văn Lang':'VLU',
# 'VLU':'VLU',
# 'Đại học FPT':'FPT',
# 'ĐH FPT':'FPT',
# 'ĐHFPT':'FPT',
# 'FPT':'FPT',
# 'ĐH Hoa Sen':'HOASEN',
# 'Đại học Hoa Sen':'HOASEN',
# 'Hoa Sen':'HOASEN',
# 'Đại học Hùng Vương':'HVU',
# 'ĐH Hùng Vương':'HVU',
# 'Hùng Vương':'HVU',
# 'HVU':'HVU',
# 'ĐH Kinh tế - Tài Chính':'UEF',
# 'ĐH KTTC':'UEF',
# 'ĐH KT- TC':'UEF',
# 'ĐHKTTC':'UEF',
# 'ĐHKT-TC':'UEF',
# 'Đại học Kinh tế TC':'UEF',
# 'Đại học KT Tài Chính':'UEF',
# 'ĐH Kinh tế TC':'UEF',
# 'ĐH KT Tài Chính':'UEF',
# 'Đại học KTTC':'UEF',
# 'Đại học KT_TC':'UEF',
# ...

# %%
df1 = pandas.read_csv('../CSV/ChuanHoaDuLieuNganh.csv')
df1
# Out:
#                   INPUT                             OUTPUT
# 0       Hữu cơ-hóa dược        Công nghệ hữu cơ - Hóa dược
# 1       Hữu cơ,hóa dược        Công nghệ hữu cơ - Hóa dược
# 2      Hữu cơ, hóa dược        Công nghệ hữu cơ - Hóa dược
# 3     Hữu cơ - hóa dược        Công nghệ hữu cơ - Hóa dược
# 4         điện, điện tử   Công nghệ kỹ thuật điện, điện tử
# ..                  ...                                ...
# 219       TK thời trang                Thiết kế thời trang
# 220  Thiết kế trang web                 Thiết kế trang web
# 221        TK trang web                 Thiết kế trang web
# 222        Thiết kế web                 Thiết kế trang web
# 223              TK web                 Thiết kế trang web
#
# [224 rows x 2 columns]

# %%
for index, row in df1.iterrows():
    print('\'' + row['INPUT'] + '\'' + ':' + '\'' + row['OUTPUT'] + '\',')
# Out:
# 'Hữu cơ-hóa dược':' Công nghệ hữu cơ - Hóa dược',
# 'Hữu cơ,hóa dược':' Công nghệ hữu cơ - Hóa dược',
# 'Hữu cơ, hóa dược':' Công nghệ hữu cơ - Hóa dược',
# 'Hữu cơ - hóa dược':' Công nghệ hữu cơ - Hóa dược',
# 'điện, điện tử':' Công nghệ kỹ thuật điện, điện tử',
# 'điện - điện tử':' Công nghệ kỹ thuật điện, điện tử',
# 'vô cơ, vật liệu':' Công nghệ Vô cơ - Vật liệu',
# 'vô cơ - vật liệu':' Công nghệ Vô cơ - Vật liệu',
# 'Đầu tư tài chính':' Đầu tư tài chính',
# 'đầu tư TC ':' Đầu tư tài chính',
# 'ĐT tài chính':' Đầu tư tài chính',
# 'Thông tin kinh doanh':' Hệ thống thông tin kinh doanh',
# 'Thông tin KD':' Hệ thống thông tin kinh doanh',
# 'TT Kinh doanh':' Hệ thống thông tin kinh doanh',
# 'hướng dẫn viên':' Hướng dẫn viên du lịch',
# 'HDV':' Hướng dẫn viên du lịch',
# 'QT dịch vụ du lịch và lữ hành':' Quản trị Dịch vụ Du lịch & Lữ hành',
# 'QT dịch vụ du lịch & lữ hành':' Quản trị Dịch vụ Du lịch & Lữ hành',
# 'QTDV du lịch và lữ hành':' Quản trị Dịch vụ Du lịch & Lữ hành',
# ...

# %%
df2 = pandas.read_csv('../CSV/Collection_KhoiThi.csv')
df2
# Out:
#     Khoi thi                      To hop mon
# 0        A00           Toán, Vật Lý, Hóa Học
# 1        A01         Toán, Vật Lý, Tiếng Anh
# 2        B00         Toán, Hóa Học, Sinh Học
# 3        C00        Ngữ Văn, Lịch Sử, Địa Lý
# 4        D01        Ngữ Văn, Toán, Tiếng Anh
# ..       ...                             ...
# 185      V07    Toán, tiếng Đức, Vẽ mỹ thuật
# 186      V08    Toán, tiếng Nga, Vẽ mỹ thuật
# 187      V09   Toán, tiếng Nhật, Vẽ mỹ thuật
# 188      V10   Toán, tiếng Pháp, Vẽ mỹ thuật
# 189      V11  Toán, tiếng Trung, Vẽ mỹ thuật
#
# [190 rows x 2 columns]

# %%
for index, row in df2.iterrows():
    print('\'' + row['Khoi thi'] + '\'' + ':' + '\'' + row['Khoi thi'] + '\',')
# Out:
# 'A00':'A00',
# 'A01':'A01',
# 'B00':'B00',
# 'C00':'C00',
# 'D01':'D01',
# 'D02':'D02',
# 'D03':'D03',
# 'D04':'D04',
# 'D05':'D05',
# 'D06':'D06',
# 'A02':'A02',
# 'A03':'A03',
# 'A04':'A04',
# 'A05':'A05',
# 'A06':'A06',
# 'A07':'A07',
# 'A08':'A08',
# 'A09':'A09',
# 'A10':'A10',
# 'A11':'A11',
# 'A12':'A12',
# 'A14':'A14',
# 'A15':'A15',
# 'A16':'A16',
# 'A17':'A17',
# 'A18':'A18',
# 'B01':'B01',
# 'B02':'B02',
# 'B03':'B03',
# 'B04':'B04',
# 'B05':'B05',
# 'B08':'B08',
# 'C01':'C01',
# 'C02':'C02',
# 'C03':'C03',
# 'C04':'C04',
# 'C05':'C05',
# 'C06':'C06',
# 'C07':'C07',
# 'C08':'C08',
# 'C09':'C09',
# 'C10':'C10',
# 'C12':'C12',
# 'C13':'C13',
# 'C14':'C14',
# 'C15':'C15',
# 'C16':'C16',
# 'C17':'C17',
# 'C19':'C19',
# 'C20':'C20',
# 'D07':'D07',
# 'D08':'D08',
# 'D09':'D09',
# 'D10':'D10',
# 'D11':'D11',
# 'D12':'D12',
# 'D13':'D13',
# 'D14':'D14',
# 'D15':'D15',
# 'D16':'D16',
# 'D17':'D17',
# 'D18':'D18',
# 'D19':'D19',
# 'D20':'D20',
# 'D21':'D21',
# 'D22':'D22',
# ...
